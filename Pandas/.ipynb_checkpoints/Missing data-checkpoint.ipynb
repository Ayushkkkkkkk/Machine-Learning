# %% [markdown]
# *Handle missing data

# %%
import pandas as pd
import numpy as np
df = pd.read_csv('ml.csv')

# %%
df
# Out:
#       Series_reference   Period  Data_value Suppressed STATUS   UNITS  \
# 0          BDCQ.SEA1AA  2011.06     80078.0        NaN      F  Number
# 1          BDCQ.SEA1AA  2011.09     78324.0        NaN      F  Number
# 2          BDCQ.SEA1AA  2011.12     85850.0        NaN      F  Number
# 3          BDCQ.SEA1AA  2012.03     90743.0        NaN      F  Number
# 4          BDCQ.SEA1AA  2012.06     81780.0        NaN      F  Number
# ...                ...      ...         ...        ...    ...     ...
# 20249    BDCQ.SEE3999A  2017.06         NaN          Y      C  Number
# 20250    BDCQ.SEE3999A  2017.09         NaN          Y      C  Number
# 20251    BDCQ.SEE3999A  2017.12         NaN          Y      C  Number
# 20252    BDCQ.SEE3999A  2018.03         NaN          Y      C  Number
# 20253    BDCQ.SEE3999A  2018.06         NaN          Y      C  Number
#
#        Magnitude                         Subject  \
# 0              0  Business Data Collection - BDC
# ...

# %%
df.head()
# Out:
#   Series_reference   Period  Data_value Suppressed STATUS   UNITS  Magnitude  \
# 0      BDCQ.SEA1AA  2011.06     80078.0        NaN      F  Number          0
# 1      BDCQ.SEA1AA  2011.09     78324.0        NaN      F  Number          0
# 2      BDCQ.SEA1AA  2011.12     85850.0        NaN      F  Number          0
# 3      BDCQ.SEA1AA  2012.03     90743.0        NaN      F  Number          0
# 4      BDCQ.SEA1AA  2012.06     81780.0        NaN      F  Number          0
#
#                           Subject                            Group  \
# 0  Business Data Collection - BDC  Industry by employment variable
# 1  Business Data Collection - BDC  Industry by employment variable
# 2  Business Data Collection - BDC  Industry by employment variable
# 3  Business Data Collection - BDC  Industry by employment variable
# 4  Business Data Collection - BDC  Industry by employment variable
#
#   Series_title_1                     Series_title_2 Series_title_3  \
# ...

# %%
new_df = df.replace([np.NaN, 0],0)

# %%
new_df
# Out:
#       Series_reference   Period  Data_value Suppressed STATUS   UNITS  \
# 0          BDCQ.SEA1AA  2011.06     80078.0          0      F  Number
# 1          BDCQ.SEA1AA  2011.09     78324.0          0      F  Number
# 2          BDCQ.SEA1AA  2011.12     85850.0          0      F  Number
# 3          BDCQ.SEA1AA  2012.03     90743.0          0      F  Number
# 4          BDCQ.SEA1AA  2012.06     81780.0          0      F  Number
# ...                ...      ...         ...        ...    ...     ...
# 20249    BDCQ.SEE3999A  2017.06         0.0          Y      C  Number
# 20250    BDCQ.SEE3999A  2017.09         0.0          Y      C  Number
# 20251    BDCQ.SEE3999A  2017.12         0.0          Y      C  Number
# 20252    BDCQ.SEE3999A  2018.03         0.0          Y      C  Number
# 20253    BDCQ.SEE3999A  2018.06         0.0          Y      C  Number
#
#        Magnitude                         Subject  \
# 0              0  Business Data Collection - BDC
# ...

# %%
new_df = df.replace({
    0 :np.NaN
})

# %%
new_df
# Out:
#       Series_reference   Period  Data_value Suppressed STATUS   UNITS  \
# 0          BDCQ.SEA1AA  2011.06     80078.0        NaN      F  Number
# 1          BDCQ.SEA1AA  2011.09     78324.0        NaN      F  Number
# 2          BDCQ.SEA1AA  2011.12     85850.0        NaN      F  Number
# 3          BDCQ.SEA1AA  2012.03     90743.0        NaN      F  Number
# 4          BDCQ.SEA1AA  2012.06     81780.0        NaN      F  Number
# ...                ...      ...         ...        ...    ...     ...
# 20249    BDCQ.SEE3999A  2017.06         NaN          Y      C  Number
# 20250    BDCQ.SEE3999A  2017.09         NaN          Y      C  Number
# 20251    BDCQ.SEE3999A  2017.12         NaN          Y      C  Number
# 20252    BDCQ.SEE3999A  2018.03         NaN          Y      C  Number
# 20253    BDCQ.SEE3999A  2018.06         NaN          Y      C  Number
#
#        Magnitude                         Subject  \
# 0            NaN  Business Data Collection - BDC
# ...

# %% [markdown]
# REGEX

# %%
new_df
# Out:
#       Series_reference   Period  Data_value Suppressed STATUS   UNITS  \
# 0          BDCQ.SEA1AA  2011.06     80078.0        NaN      F  Number
# 1          BDCQ.SEA1AA  2011.09     78324.0        NaN      F  Number
# 2          BDCQ.SEA1AA  2011.12     85850.0        NaN      F  Number
# 3          BDCQ.SEA1AA  2012.03     90743.0        NaN      F  Number
# 4          BDCQ.SEA1AA  2012.06     81780.0        NaN      F  Number
# ...                ...      ...         ...        ...    ...     ...
# 20249    BDCQ.SEE3999A  2017.06         NaN          Y      C  Number
# 20250    BDCQ.SEE3999A  2017.09         NaN          Y      C  Number
# 20251    BDCQ.SEE3999A  2017.12         NaN          Y      C  Number
# 20252    BDCQ.SEE3999A  2018.03         NaN          Y      C  Number
# 20253    BDCQ.SEE3999A  2018.06         NaN          Y      C  Number
#
#        Magnitude                         Subject  \
# 0            NaN  Business Data Collection - BDC
# ...

# %%
df
# Out:
#       Series_reference   Period  Data_value Suppressed STATUS   UNITS  \
# 0          BDCQ.SEA1AA  2011.06     80078.0        NaN      F  Number
# 1          BDCQ.SEA1AA  2011.09     78324.0        NaN      F  Number
# 2          BDCQ.SEA1AA  2011.12     85850.0        NaN      F  Number
# 3          BDCQ.SEA1AA  2012.03     90743.0        NaN      F  Number
# 4          BDCQ.SEA1AA  2012.06     81780.0        NaN      F  Number
# ...                ...      ...         ...        ...    ...     ...
# 20249    BDCQ.SEE3999A  2017.06         NaN          Y      C  Number
# 20250    BDCQ.SEE3999A  2017.09         NaN          Y      C  Number
# 20251    BDCQ.SEE3999A  2017.12         NaN          Y      C  Number
# 20252    BDCQ.SEE3999A  2018.03         NaN          Y      C  Number
# 20253    BDCQ.SEE3999A  2018.06         NaN          Y      C  Number
#
#        Magnitude                         Subject  \
# 0              0  Business Data Collection - BDC
# ...

# %%
df.head()
# Out:
#   Series_reference   Period  Data_value Suppressed STATUS   UNITS  Magnitude  \
# 0      BDCQ.SEA1AA  2011.06     80078.0        NaN      F  Number          0
# 1      BDCQ.SEA1AA  2011.09     78324.0        NaN      F  Number          0
# 2      BDCQ.SEA1AA  2011.12     85850.0        NaN      F  Number          0
# 3      BDCQ.SEA1AA  2012.03     90743.0        NaN      F  Number          0
# 4      BDCQ.SEA1AA  2012.06     81780.0        NaN      F  Number          0
#
#                           Subject                            Group  \
# 0  Business Data Collection - BDC  Industry by employment variable
# 1  Business Data Collection - BDC  Industry by employment variable
# 2  Business Data Collection - BDC  Industry by employment variable
# 3  Business Data Collection - BDC  Industry by employment variable
# 4  Business Data Collection - BDC  Industry by employment variable
#
#   Series_title_1                     Series_title_2 Series_title_3  \
# ...

# %%
g = df.groupby('Data_value')

# %%
g

# %%
for Data_value , data in g:
# Out:
#   Cell In [13], line 1
#     for Data_value , data in g:
#                                ^
# SyntaxError: incomplete input

# %%
count = 0
for a , b in g:
    print(a)
    print(b)
    count+=1
    if count==10:
        break
# Out:
# 1.225683
#       Series_reference   Period  Data_value Suppressed STATUS  UNITS  \
# 16803    BDCQ.SEE2067A  2022.06    1.225683        NaN      F  Value
#
#        Magnitude                         Subject  \
# 16803          6  Business Data Collection - BDC
#
#                                               Group  Series_title_1  \
# 16803  Territorial authority by employment variable  Total earnings
#
#                   Series_title_2 Series_title_3  Series_title_4  \
# 16803  Chatham Islands Territory         Actual             NaN
#
#        Series_title_5
# 16803             NaN
# 1.249078
#       Series_reference   Period  Data_value Suppressed STATUS  UNITS  \
# 16800    BDCQ.SEE2067A  2021.09    1.249078        NaN      F  Value
#
#        Magnitude                         Subject  \
# 16800          6  Business Data Collection - BDC
#
#                                               Group  Series_title_1  \
# ...

# %%
g.max()
# Out:
#              Series_reference   Period  Suppressed STATUS   UNITS  Magnitude  \
# Data_value
# 1.225683e+00    BDCQ.SEE2067A  2022.06         NaN      F   Value          6
# 1.249078e+00    BDCQ.SEE2067A  2021.09         NaN      F   Value          6
# 1.257697e+00    BDCQ.SEE2067A  2021.06         NaN      F   Value          6
# 1.263092e+00    BDCQ.SEE2067A  2020.09         NaN      F   Value          6
# 1.269285e+00    BDCQ.SEE2067A  2020.06         NaN      F   Value          6
# ...                       ...      ...         ...    ...     ...        ...
# 2.177024e+06      BDCQ.SEA1ZS  2022.03         NaN      R  Number          0
# 2.178241e+06      BDCQ.SEA1ZA  2022.03         NaN      F  Number          0
# 2.187716e+06      BDCQ.SEA1ZA  2022.06         NaN      F  Number          0
# 2.188347e+06      BDCQ.SEA1ZS  2022.06         NaN      F  Number          0
# 2.196974e+06      BDCQ.SEA1ZA  2021.12         NaN      F  Number          0
#
# ...

# %%
g.mean()
# Out:
#                Period  Magnitude  Series_title_4  Series_title_5
# Data_value
# 1.225683e+00  2022.06        6.0             NaN             NaN
# 1.249078e+00  2021.09        6.0             NaN             NaN
# 1.257697e+00  2021.06        6.0             NaN             NaN
# 1.263092e+00  2020.09        6.0             NaN             NaN
# 1.269285e+00  2020.06        6.0             NaN             NaN
# ...               ...        ...             ...             ...
# 2.177024e+06  2022.03        0.0             NaN             NaN
# 2.178241e+06  2022.03        0.0             NaN             NaN
# 2.187716e+06  2022.06        0.0             NaN             NaN
# 2.188347e+06  2022.06        0.0             NaN             NaN
# 2.196974e+06  2021.12        0.0             NaN             NaN
#
# [14143 rows x 4 columns]

# %%
import matplotlib
# %matplotlib inline
g.plot()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In [21], line 1
# ----> 1 import matplotlib
#       2 get_ipython().run_line_magic('matplotlib', 'inline')
#       3 g.plot()
#
# ModuleNotFoundError: No module named 'matplotlib'
